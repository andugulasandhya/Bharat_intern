# %% [markdown]
# <a href="https://colab.research.google.com/github/andugulasandhya/Bharat_intern/blob/main/untitled89.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("/content/archive (21).zip")
data.head()
# Out:
#    0.00632   18  2.31  0  0.538  6.575  65.2    4.09  1  296  15.3   396.9  \
# 0  0.02731  0.0  7.07  0  0.469  6.421  78.9  4.9671  2  242  17.8  396.90
# 1  0.02729  0.0  7.07  0  0.469  7.185  61.1  4.9671  2  242  17.8  392.83
# 2  0.03237  0.0  2.18  0  0.458  6.998  45.8  6.0622  3  222  18.7  394.63
# 3  0.06905  0.0  2.18  0  0.458  7.147  54.2  6.0622  3  222  18.7  396.90
# 4  0.02985  0.0  2.18  0  0.458  6.430  58.7  6.0622  3  222  18.7  394.12
#
#    4.98    24
# 0  9.14  21.6
# 1  4.03  34.7
# 2  2.94  33.4
# 3  5.33  36.2
# 4  5.21  28.7

# %%
df=pd.DataFrame(data,index=None)
target_column_name="24"
df[target_column_name]=data[target_column_name]

# %%
independent=df.columns.difference(df[target_column_name])

# %%
print(independent)
# Out:
# Index(['0', '0.00632', '0.538', '1', '15.3', '18', '2.31', '24', '296',
#        '396.9', '4.09', '4.98', '6.575', '65.2'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
df[independent]=scaler.fit_transform(df[independent])

# %%
from sklearn.model_selection import train_test_split
x_train,y_train,x_test,y_test=train_test_split(df[independent],df[target_column_name])

# %%
from sklearn.metrics.pairwise import cosine_similarity
cos_sine=cosine_similarity(df.iloc[[0]],df.iloc[[1]])

# %%
print(cos_sine)
# Out:
# [[0.72241186]]
