# %% [markdown]
# <a href="https://colab.research.google.com/github/andugulasandhya/Bharat_intern/blob/main/exp9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
iris_df = pd.read_csv('/content/archive (27).zip')
x = iris_df.drop('species', axis=1)
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)
clustering=AgglomerativeClustering(n_clusters=3,linkage='ward')
clustering.fit(x_scaled)
plt.scatter(x_scaled[:,0], x_scaled[:,1], c=clustering.labels_,cmap='viridis')
plt.show()
